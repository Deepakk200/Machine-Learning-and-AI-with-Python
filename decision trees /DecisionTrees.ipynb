# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepakk200/Machine-Learning-and-AI-with-Python/blob/main/decision%20trees%20/DecisionTrees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn import tree
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score



pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 20)
plt.rcParams["figure.figsize"] = (12,8)



elect_train = pd.read_csv("/content/drive/MyDrive/datasets/county_election_train.csv")

elect_test = pd.read_csv("/content/drive/MyDrive/datasets/county_election_test.csv")
elect_train.head()
# Out:
#      state  fipscode          county  population  hispanic  minority  female  unemployed  income  \
# 0  Alabama      1001  Autauga County       50756     2.842    22.733  51.475         5.2   54366
# 1  Alabama      1003  Baldwin County      179878     4.550    12.934  51.261         5.5   49626
# 2  Alabama      1007     Bibb County       21587     2.409    23.930  46.110         6.6   39546
# 3  Alabama      1009   Blount County       58345     8.954     4.229  50.592         5.4   45567
# 4  Alabama      1011  Bullock County       10985     7.526    72.831  45.241         7.8   26580
#
#    nodegree  bachelor  inactivity  obesity  density  cancer   trump  clinton  votergap
# 0      13.8      21.9        28.6     34.1     91.8   186.5  73.436   23.957    49.479
# 1      11.0      28.6        22.3     27.4    114.6   229.4  77.351   19.565    57.786
# 2      22.1      10.2        33.9     40.3     36.8   230.3  76.966   21.422    55.544
# ...

# %%
#
# Using different colours to depict data points associated with Trump and Clinton
# Ensure the results are binary i.e. 0s or 1s
y_train = (elect_train['trump'] > elect_train['clinton']).astype(int)

# Ensure the results are binary i.e. 0s or 1
y_test = (elect_test['trump'] > elect_test['clinton']).astype(int)


plt.scatter(elect_train['trump'] , elect_train['clinton'] , marker = "." , color = 'blue' ,label = "Trump" ,s = 50 , alpha = 0.4)
plt.scatter(elect_train['trump'] , elect_train['clinton'] , marker = "." ,color = 'green' , label = "Cinton ",s = 50 ,  alpha = 0.4)
plt.legend()
plt.show()

# %%
# Choosing Gini as the splitting criteria
dtree = DecisionTreeClassifier(max_depth = 3 , criterion='gini')
# the minority column as the predictor variable
dtree.fit(elect_train[['minority']], y_train )
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
plt.figure(figsize =(30 , 20))
tree.plot_tree(dtree, filled = True,feature_names=['minority'], class_names=['Clinton', 'Trump'])
plt.show()
